# %%
import glob
from codecs import open

import pandas as pd
import numpy as np
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# %env GOOGLE_APPLICATION_CREDENTIALS=/Users/emersonsjsu/GitHub/EarlGrey/google_private_key.json
WORKING_DIRECTORY = "/Users/emersonsjsu/GitHub/EarlGrey"
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/Users/emersonsjsu/GitHub/EarlGrey/google_private_key.json

# %%
my_index = pd.MultiIndex(levels=[[], []],
                         labels=[[], []],
                         names=[u'character_name', u'episode_no'])
my_columns = [u'text',u'sentiment_score',u'sentiment_magnitude']
char_df = pd.DataFrame(index=my_index, columns=my_columns)
char_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>text</th>
#       <th>sentiment_score</th>
#       <th>sentiment_magnitude</th>
#     </tr>
#     <tr>
#       <th>character_name</th>
#       <th>episode_no</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
# Clear char_df
char_df = char_df.iloc[0:0]
FIRST_EPISODE_OFFSET = 101


def sanitize_name(name_line):
    name = name_line.strip()  # Voice overs count as same character
    if name.endswith('V.O.'):
        name = name[:-5]
    # Strip parentheticals from name
    if name.find('(') != -1:
        name = name[:name.find('(')]
    # Strip 'S VOICE from name
    if name.endswith('\'S VOICE'):
        name = name[:-8]
    # Strip 'S COM VOICE from name
    if name.endswith('\'S COM VOICE'):
        name = name[:-12]
    return name.strip()


for file_path in glob.glob(WORKING_DIRECTORY+'/scripts/225.txt'):  # Only read one file for debug purposes
# for file_path in glob.glob(WORKING_DIRECTORY+'/scripts/*.txt'):
    current_file = open(file_path, "r", encoding='utf-8', errors="ignore")
    episode_no = int(current_file.name[current_file.name.rfind('/') + 1:-4]) - FIRST_EPISODE_OFFSET
    lines = current_file.readlines()
    character_name = ''
    for line in lines:
        # Character dialogue has ended, reset current character
        if line.strip() == '':
            character_name = ''
        # All names are preceded by exactly 5 tabs
        elif line[:5] == '\t\t\t\t\t' and line[5:6] != '\t' and not line.strip().startswith('('):
            # We have found a name! Update current name
            character_name = sanitize_name(line)
        # If we are still looking at a character's dialogue
        elif character_name != '':
            line_text = line.strip()
            # Previous dialogue found for character this episode, append line to previous text
            if (character_name, episode_no) in char_df.index:
                char_df.loc[(character_name, episode_no), 'text'] += ' ' + line_text
            # First dialogue for character this episode, initialize string list
            else:
                char_df.loc[(character_name, episode_no), 'text'] = line_text
char_df.loc[('PICARD',124),'text']
# Out:
# u'Captain\'s log, stardate 45944.1. We\'re en route to Starbase Two-eighteen after a magnetic wave survey of the Parvenium Sector. We will give our report directly to Fleet Admiral Gustafson. The last time I encountered Admiral Gustafson... I ended up spending nine straight hours at the opera. The entire "Ring" cycle at one sitting... And for me... but not, apparently, for Admiral Gustafson. She went back the next day and sat through it all again. I warned her that this time -- On screen. Magnify. Mister Data? Increase power to -- Where is this... ? Computer, freeze program. (beat) End program. Picard to Enterprise -- I asked you... what is this place? Where is my uniform? My communicator? I am Captain Jean-Luc Picard of the Federation Starship Enterprise. I would like to speak with whoever is in charge here. Just tell me this -- am I a prisoner here? Are you in charge here? I want to be returned to my ship immediately. Please... if you could tell me... what is this place? Where am I? That must be it. Perhaps you could help me... My name is Kamin... and you are -- ? Ah. And you say I\'ve been ill... Eline. And... what is this place? Please -- I\'m sure it will come back to me... What planet? I\'m really quite all right. If you\'ll just answer... Kataan... not a Federation planet. I think I\'ll take a walk... Exercise will do me good. I\'d like to -- re-acquaint myself with the surroundings. Hungry, thirsty... weary... I suppose that proves this isn\'t a dream, doesn\'t it? It\'s not my life... I know that much. I walked. For hours. This is delicious... Would you -- answer some questions for me? No matter how strange they might seem to you? Are there other planets in this star system? Do you visit any other systems... ? All right. Is there any kind of communication system here? How do you send messages to... to other communities? Other places? Yes. When can that be arranged? Of course. Anything you can tell me would be helpful. We are... married? What is it that I do... here in Ressik? The flute? And when did I learn to play it? I see what you mean. Thank you for the soup. And for your help. Tomorrow will you help me send a message? I\'ll sleep here... I\'ve been sick... I may be tossing and turning... it wouldn\'t be fair to you. Where did you get this? I\'m just charting the sun\'s movements. It might give some clues to the cause of this drought. The memory\'s five years old now, but it\'s still inside me. (shrugs) My other existence may be gone, but I still wonder about it. Eline... It was real... as real as this is. You can\'t expect me to forget the lifetime I spent there... I know this has been hard for you... You have been amazingly tolerant. Good morning, Batai... Yes... (to Eline) Will you come along? It isn\'t her fault. These last few years have been difficult for her. If the weather pattern doesn\'t change, rationing won\'t be enough. We will run out of water. No. I haven\'t spoken to you before. I suggest we build atmospheric condensers which could extract water from the air. Iron weaving. (beat) And playing the flute. Each community would be responsible for its own. These condensers could mean the difference between watering our crops... or watching them die. We\'ll never see an atmospheric condenser... Come to dinner tonight, my friend. I\'ll make a vegetable stew. We\'ll talk about building our own condenser. I\'m not brooding. I\'m immersed in my music. (re: flute) I\'ve found it helps me think. (a smile) The real surprise is that I enjoy it so much. Goodnight, my friend. Yes, ma\'am. I\'m the one who\'s sorry. (beat) Everything you said this morning was absolutely right. I\'ve given you so little... and you have given me so much... tenderness, patience... and a good talking to when I needed it. (beat) You\'ve been more than I could ever have hoped for. More than I deserve. Not such a wonderful husband. I spend my spare time charting the stars... I disappear for days at a time exploring the countryside... and I ...

# %%
def analyze(text):
    client = language.LanguageServiceClient()
    document = types.Document(
        content=text,
        type=enums.Document.Type.PLAIN_TEXT
    )
    annotations = client.analyze_sentiment(document=document)
    return annotations.document_sentiment.score, annotations.document_sentiment.magnitude


char_df['sentiment_score'], char_df['sentiment_magnitude'] = np.vectorize(analyze)(char_df['text'])
char_df.shape
# Out:
# (153, 3)

# %%
char_df.to_pickle(WORKING_DIRECTORY+'/char_df.pickle')

# %%
temp = pd.read_pickle(WORKING_DIRECTORY+'/char_df.pickle')
temp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>text</th>
#       <th>sentiment_score</th>
#       <th>sentiment_magnitude</th>
#     </tr>
#     <tr>
#       <th>character_name</th>
#       <th>episode_no</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TROI</th>
#       <th>176</th>
#       <td>That was an incredible program. Worf, we were ...</td>
#       <td>0.1</td>
#       <td>17.400000</td>
#     </tr>
#     <tr>
#       <th>WORF</th>
#       <th>176</th>
#       <td>I am glad you approve. I have always found the...</td>
#       <td>0.0</td>
#       <td>15.700000</td>
#     </tr>
#     <tr>
#       <th>TROI</th>
#       <th>176</th>
#       <td>I should take my own advice and use it to rela...</td>
#       <td>0.5</td>
#       <td>1.600000</td>
#     </tr>
#     <tr>
#       <th>PICARD</th>
#       <th>176</th>
#       <td>Counselor! (urgent) What's today's date? The d...</td>
#       <td>0.0</td>
#       <td>137.000000</td>
#     </tr>
#     <tr>
#       <th>GEORDI</th>
#       <th>176</th>
#       <td>(calls out) Captain Picard to the Bridge! (wit...</td>
#       <td>0.0</td>
#       <td>21.100000</td>
#     </tr>
#     <tr>
#       <th>TASHA</th>
#       <th>176</th>
#       <td>Captain? Are you all right, sir? Sir... ? I wa...</td>
#       <td>0.0</td>
#       <td>7.300000</td>
#     </tr>
#     <tr>
#       <th>COM VOICE</th>
#       <th>176</th>
#       <td>Enterprise to Shuttlecraft Galileo. You are cl...</td>
#       <td>0.0</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <th>BEVERLY</th>
#       <th>176</th>
#       <td>I've finished the neurographic scan. I don't s...</td>
#       <td>0.0</td>
#       <td>30.799999</td>
#     </tr>
#     <tr>
#       <th>OGAWA</th>
#       <th>176</th>
#       <td>The bio-spectral test results, Doctor. Doctor....</td>
#       <td>0.0</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <th>BEVERLY</th>
#       <th>176</th>
#       <td>If you'd been somewhere else, there would be s...</td>
#       <td>-0.2</td>
#       <td>1.700000</td>
#     </tr>
#     <tr>
#       <th>RIKER</th>
#       <th>176</th>
#       <td>No, sir. His security scans came up negative. ...</td>
#       <td>0.0</td>
#       <td>16.799999</td>
#     </tr>
#     <tr>
#       <th>RIKER</th>
#       <th>176</th>
#       <td>They're checking the sensor logs... but there'...</td>
#       <td>-0.3</td>
#       <td>1.600000</td>
#     </tr>
#     <tr>
#       <th>NAKAMURA</th>
#       <th>176</th>
#       <td>Captain. I'm initiating a fleetwide Yellow Ale...</td>
#       <td>0.0</td>
#       <td>1.500000</td>
#     </tr>
#     <tr>
#       <th>PICARD</th>
#       <th>176</th>
#       <td>(suddenly unsure) At least, I think it was... ...</td>
#       <td>0.0</td>
#       <td>3.800000</td>
#     </tr>
#     <tr>
#       <th>JESSEL</th>
#       <th>176</th>
#       <td>(to Picard) How do you like your tea? Of cours...</td>
#       <td>-0.1</td>
#       <td>1.100000</td>
#     </tr>
#     <tr>
#       <th>DATA</th>
#       <th>176</th>
#       <td>Holding the Lucasian Chair does have its perqu...</td>
#       <td>0.0</td>
#       <td>40.500000</td>
#     </tr>
#     <tr>
#       <th>O'BRIEN</th>
#       <th>176</th>
#       <td>Captain Picard to the Bridge, Please. Sir, Sta...</td>
#       <td>0.0</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>CHILTON</th>
#       <th>176</th>
#       <td>Captain Picard? (beat) Captain, McKinley Stati...</td>
#       <td>0.1</td>
#       <td>2.800000</td>
#     </tr>
#     <tr>
#       <th>Q</th>
#       <th>176</th>
#       <td>Mon Capitan... I thought you'd never get here....</td>
#       <td>0.0</td>
#       <td>35.400002</td>
#     </tr>
#     <tr>
#       <th>YOUNG RIKER</th>
#       <th>176</th>
#       <td>Understood.</td>
#       <td>0.1</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <th>COMPUTER VOICE</th>
#       <th>176</th>
#       <td>That beverage has not been programmed into the...</td>
#       <td>-0.1</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>TOMOLAK</th>
#       <th>176</th>
#       <td>So Captain... how long shall we stare at each ...</td>
#       <td>0.1</td>
#       <td>1.900000</td>
#     </tr>
#     <tr>
#       <th>ANDRONA</th>
#       <th>176</th>
#       <td>Enterprise, you are a welcome sight. We've bee...</td>
#       <td>0.1</td>
#       <td>3.900000</td>
#     </tr>
#     <tr>
#       <th>GAINES</th>
#       <th>176</th>
#       <td>(to Riker, off console) All the Pasteur crew i...</td>
#       <td>0.0</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>Q</th>
#       <th>176</th>
#       <td>The building blocks of what you call "life".</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>ENSIGN</th>
#       <th>176</th>
#       <td>Two decks up, sir. Section zero zero five.</td>
#       <td>0.2</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>GAINES' COM VOICE</th>
#       <th>176</th>
#       <td>Aye, sir.</td>
#       <td>0.4</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <th>PICARD</th>
#       <th>2</th>
#       <td>Captain's log, Stardate 41209.2. We are runnin...</td>
#       <td>-0.1</td>
#       <td>4.000000</td>
#     </tr>
#     <tr>
#       <th>WOMAN</th>
#       <th>2</th>
#       <td>Well, hello Enterprise. Welcome... I hope you ...</td>
#       <td>0.2</td>
#       <td>2.500000</td>
#     </tr>
#     <tr>
#       <th>DATA</th>
#       <th>2</th>
#       <td>(touches com panel) S.S. Tsiolkovsky, repeat y...</td>
#       <td>0.0</td>
#       <td>15.100000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>K'MPEC</th>
#       <th>80</th>
#       <td>It's about time you arrived, Picard. Didn't sh...</td>
#       <td>0.0</td>
#       <td>12.800000</td>
#     </tr>
#     <tr>
#       <th>ALEXANDER</th>
#       <th>80</th>
#       <td>I would have won! Where are the other Klingons...</td>
#       <td>0.0</td>
#       <td>1.300000</td>
#     </tr>
#     <tr>
#       <th>K'EHLEYR</th>
#       <th>80</th>
#       <td>Why the sudden concern? You won't even acknowl...</td>
#       <td>-0.7</td>
#       <td>1.400000</td>
#     </tr>
#     <tr>
#       <th>DURAS</th>
#       <th>80</th>
#       <td>Let's get this over with, Picard. Even in deat...</td>
#       <td>-0.1</td>
#       <td>11.700000</td>
#     </tr>
#     <tr>
#       <th>GOWRON</th>
#       <th>80</th>
#       <td>Qab jIH nagil! What do you know of Klingon law...</td>
#       <td>0.0</td>
#       <td>6.600000</td>
#     </tr>
#     <tr>
#       <th>GEORDI</th>
#       <th>80</th>
#       <td>(to Riker) We've completed our analysis of the...</td>
#       <td>0.3</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>COMPUTER VOICE</th>
#       <th>80</th>
#       <td>Stardates 43685 through 43689. Forty-three off...</td>
#       <td>0.0</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>GUARD#2</th>
#       <th>80</th>
#       <td>Priority message to you from the home planet o...</td>
#       <td>-0.2</td>
#       <td>2.100000</td>
#     </tr>
#     <tr>
#       <th>SECURITY OFFICER</th>
#       <th>80</th>
#       <td>Excuse me, sir... Sir, you cannot leave your q...</td>
#       <td>0.1</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <th>BEVERLY</th>
#       <th>80</th>
#       <td>One of the Klingons who died in the explosion ...</td>
#       <td>-0.1</td>
#       <td>4.400000</td>
#     </tr>
#     <tr>
#       <th>BEVERLY</th>
#       <th>80</th>
#       <td>(he reacts) The bomb was implanted in one of t...</td>
#       <td>0.6</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <th>GUARD</th>
#       <th>80</th>
#       <td>He has claimed the right of vengeance.</td>
#       <td>0.1</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <th>WORF</th>
#       <th>79</th>
#       <td>(scowls) One. Pah. I suspect conspiracy. But f...</td>
#       <td>0.0</td>
#       <td>8.800000</td>
#     </tr>
#     <tr>
#       <th>RIKER</th>
#       <th>79</th>
#       <td>(baiting him) Worf. Are you trying to fill ano...</td>
#       <td>0.0</td>
#       <td>25.200001</td>
#     </tr>
#     <tr>
#       <th>TROI</th>
#       <th>79</th>
#       <td>(to Riker) I fold. (teasingly) You two have su...</td>
#       <td>0.0</td>
#       <td>4.900000</td>
#     </tr>
#     <tr>
#       <th>DATA</th>
#       <th>79</th>
#       <td>I will raise you three. I will see your bet, a...</td>
#       <td>0.0</td>
#       <td>35.500000</td>
#     </tr>
#     <tr>
#       <th>RIKER</th>
#       <th>79</th>
#       <td>Now lose it in the deck. Geordi -- what's taki...</td>
#       <td>0.0</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <th>PICARD</th>
#       <th>79</th>
#       <td>Picard to Riker. We've received a distress cal...</td>
#       <td>0.0</td>
#       <td>19.600000</td>
#     </tr>
#     <tr>
#       <th>PICARD</th>
#       <th>79</th>
#       <td>Captain's log, stardate 44215.2. The Enterpris...</td>
#       <td>0.0</td>
#       <td>1.600000</td>
#     </tr>
#     <tr>
#       <th>TAN TSU</th>
#       <th>79</th>
#       <td>Enterprise, this is Tan Tsu, Arcos engineer. E...</td>
#       <td>0.0</td>
#       <td>1.500000</td>
#     </tr>
#     <tr>
#       <th>O'BRIEN</th>
#       <th>79</th>
#       <td>Aye, Captain. (to com) There's nothing to lock...</td>
#       <td>0.0</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>WORF</th>
#       <th>79</th>
#       <td>Perhaps the Doctor should wait here for our si...</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>BEVERLY</th>
#       <th>79</th>
#       <td>(an edge) I appreciate the concern. But I thin...</td>
#       <td>0.2</td>
#       <td>5.300000</td>
#     </tr>
#     <tr>
#       <th>MAN #1</th>
#       <th>79</th>
#       <td>Identify yourselves. Possibly. It depends on w...</td>
#       <td>0.0</td>
#       <td>0.800000</td>
#     </tr>
#     <tr>
#       <th>HAYNE</th>
#       <th>79</th>
#       <td>(to Riker) The Alliance is holding your men ho...</td>
#       <td>0.0</td>
#       <td>12.200000</td>
#     </tr>
#     <tr>
#       <th>ISHARA</th>
#       <th>79</th>
#       <td>Tasha was my sister. I know Alliance territory...</td>
#       <td>0.0</td>
#       <td>35.599998</td>
#     </tr>
#     <tr>
#       <th>GEORDI</th>
#       <th>79</th>
#       <td>Tasha left you in the middle of all that? If I...</td>
#       <td>0.0</td>
#       <td>3.300000</td>
#     </tr>
#     <tr>
#       <th>ISHARA</th>
#       <th>79</th>
#       <td>Access tunnels are here... But you don't. Righ...</td>
#       <td>0.3</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>GEORDI</th>
#       <th>79</th>
#       <td>(continuing) And that's about two kilometers o...</td>
#       <td>0.2</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <th>DATA</th>
#       <th>79</th>
#       <td>Ishara.</td>
#       <td>0.1</td>
#       <td>0.100000</td>
#     </tr>
#   </tbody>
# </table>
# <p>153 rows × 3 columns</p>
# </div>

# %%
char_df.loc[('PICARD',124),'text']
# Out:
# u'Captain\'s log, stardate 45944.1. We\'re en route to Starbase Two-eighteen after a magnetic wave survey of the Parvenium Sector. We will give our report directly to Fleet Admiral Gustafson.  4    INT. BRIDGE  PICARD, RIKER, DATA, WORF, and GEORDI at their positions; N.D.\'s as necessary. There is a light-hearted mood on the bridge.  The last time I encountered Admiral Gustafson... I ended up spending nine straight hours at the opera.  The entire "Ring" cycle at one sitting...  And for me... but not, apparently, for Admiral Gustafson. She went back the next day and sat through it all again. I warned her that this time --  STAR TREK: "The Inner Light" - 3/24/92 - TEASER       2.  4    CONTINUED:  On screen.  5    ANGLE - VIEWSCREEN (OPTICAL)  An alien object of unusual shape can be seen, though still at quite a distance. Picard moves toward the screen, between t conn and ops.  Magnify.  The object springs into greater relief. It is strange, and somehow foreboding.  Mister Data?  Increase power to --  Suddenly Picard staggers backward, as though struck. He sags, losing consciousness. Riker is already rushing to him as he begins falling.  Where is this... ?  A frown of concern on the woman\'s face.  Computer, freeze program. (beat) End program.  Nothing. The woman keeps moving, trying to blot his forehead. He gets to his feet, automatically reaching for his communicator.  Picard to Enterprise --  But there is nothing there to hit. He looks down at his garb -- strange and alien.  I asked you... what is this place?  Her look is of loving concern.  Where is my uniform? My communicator?  She looks truly worried.  I am Captain Jean-Luc Picard of the Federation Starship Enterprise. I would like to speak with whoever is in charge here.  Just tell me this -- am I a prisoner here?  Her eyes widen in alarm.  Are you in charge here?  Batai is a bit taken aback by the brusque question.  I want to be returned to my ship immediately.  The group has a reaction to this... exchanging curious glances. Batai moves closer to Picard.  Please... if you could tell me... what is this place? Where am I?  That must be it. Perhaps you could help me...  My name is Kamin... and you are -- ?  Ah. And you say I\'ve been ill...  Eline.  And... what is this place?  Batai becomes wary again, alarmed by his friend\'s total memory loss.  Please -- I\'m sure it will come back to me...  What planet?  Batai appears mystified, then comes toward Picard, puts an arm around his shoulder.  I\'m really quite all right. If you\'ll just answer...  STAR TREK: "The Inner Light" - REV. 3/26/92 - ACT ONE    9.  14   CONTINUED: (3)  Kataan... not a Federation planet.  Batai looks at him, puzzled. Picard gives the group a reassuring smile.  I think I\'ll take a walk...  A hesitation.  Exercise will do me good. I\'d like to -- re-acquaint myself with the surroundings.  He gives a nod, then begins to stride purposefully out of the square. Batai stares after him, as do the mystified townspeople.  15 thru\tOMITTED 16  16A  EXT. FIELDS - DAY  Picard roams the hills beyond the town, searching for clues to his mysterious abduction. He climbs a small ridge, stares off in the distance, then climbs down and proceeds on his way.  17   OMITTED  18   INT. KAMIN MAIN ROOM - NIGHT  Eline sits at a small table, idly stirring soup in a bowl, when she hears something outside. She jumps up, goes to the door, activates it. Picard is standing there, bone-weary.  Hungry, thirsty... weary... I suppose that proves this isn\'t a dream, doesn\'t it?  She stands, stunned, staring at him.  It\'s not my life... I know that much.  Stricken, she blinks away tears, turns to get food.  I walked. For hours.  He begins eating the soup.  This is delicious...  STAR TREK: "The Inner Light" - REV. 3/26/92 - ACT ONE   11.  18   CONTINUED: (2)  Would you -- answer some questions for me? No matter how strange they might seem to you?  Are there other planets in this star system? Do you visit any other systems... ?  Shocked ...
